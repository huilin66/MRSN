# %%
model_list = [
    # 'unet_BW',
    # 'deeplabv3p_BW',
    # 'ocrnet_BW',
    # 'segformer_BW',
    # 'cxup_1b_BW',
    # 'cxup_2b_BW',
    # 'cxup_3b_BW',
    # 'cxup_4b_BW',
    # 'cxup_4b_BW_loss',
    'cxup_4b_BW_CA_FLASH_v6',
    # 'cxup_4b_BW_CA_FLASH_v5_loss',
    # 'cxup_4b2h_BW',
    # 'cxup_4b_BW_CA_FLASH',
    # 'cxup_4b_BW_CA_FLASH_loss',
]

# %%
# pre test
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    # !python -m paddle.distributed.launch python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 20 --save_interval 100 --batch_size=1 --log_iters 10
    # !CUDA_VISIBLE_DEVICES=0 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 50 --save_interval 100 --batch_size=8 --log_iters 10
# Out:
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/utils/cpp_extension/extension_utils.py:712: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# 2026-06-11 10:47:32 [INFO]	Log file: ./log/train/cxup_4b_BW_CA_FLASH_v6_20260611_104732.log
# 2026-06-11 10:47:32 [INFO]
# ------------Environment Information-------------
# platform: Linux-5.15.0-92-generic-x86_64-with-glibc2.35
# Python: 3.10.20 | packaged by conda-forge | (main, Mar  5 2026, 16:42:22) [GCC 14.3.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_11.5.r11.5/compiler.30672275_0
# cudnn: 90.5
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: 0
# GPU: ['GPU 0: NVIDIA RTX', 'GPU 1: NVIDIA RTX']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PaddlePaddle: 3.3.1
# OpenCV: 4.13.0
# ------------------------------------------------
# 2026-06-11 10:47:32 [INFO]
# ---------------Config Information---------------
# train_dataset:
#   type: RS_MD3B
#   dataset_root: /localnvme/data/other/C2Seg_BW/train/
#   train_path: /localnvme/data/other/C2Seg_BW/train.txt
#   num_classes: 14
#   transforms:
#   - type: Normalize2
#     mean1: [511.299, 664.097, 769.063, 1248.104, -15.968, -24.247]
#     mean2: [999.433, 986.904, 974.447, 960.982, 947.575, 935.621, 924.243, 915.542, 907.726, 905.25, 909.091, 907.068, 902.661, 901.638, 902.661, 905.772, 911.386, 915.995, 920.723, 926.349, 931.746, 938.978,
#       946.329, 961.263, 959.789, 957.446, 954.46, 955.459, 954.627, 948.609, 945.025, 944.374, 949.51, 955.58, 960.178, 970.076, 975.216, 984.512, 990.831, 985.008, 950.914, 919.385, 889.296, 862.777, 825.307,
#       788.723, 762.22, 743.14, 734.277, 732.632, 733.673, 742.012, 753.558, 775.226, 794.269, 801.276, 799.636, 804.197, 816.373, 821.174, 854.051, 868.974, 869.269, 866.709, 876.802, 871.139, 835.212,
#       802.712, 767.638, 740.126, 713.945, 702.162, 696.747, 712.822, 763.065, 827.185, 896.042, 921.248, 940.171, 972.243, 1006.637, 1009.505, 990.419, 976.739, 949.181, 937.05, 925.81, 927.843, 919.324,
#     std2: [262.658, 264.218, 266.238, 268.52, 271.314, 274.417, 277.69, 281.143, 283.609, 285.875, 290.075, 291.693, 292.987, 294.783, 297.264, 300.135, 304.173, 307.715, 311.216, 315.269, 319.666, 324.806,
#       330.629, 339.265, 342.287, 345.117, 347.39, 349.633, 349.462, 345.958, 341.043, 335.233, 330.31, 325.421, 321.263, 320.142, 319.573, 322.109, 324.541, 323.369, 313.437, 304.176, 295.106, 287.168,
#       275.492, 263.964, 255.904, 250.446, 248.273, 248.307, 249.869, 253.019, 256.607, 263.015, 268.048, 269.423, 268.091, 269.031, 271.468, 271.956, 280.045, 282.251, 280.115, 277.253, 279.424, 276.046,
#       262.96, 250.279, 237.595, 227.998, 219.871, 217.434, 217.565, 224.737, 242.565, 265.104, 287.018, 296.602, 304.602, 317.398, 332.026, 335.748, 332.952, 333.034, 330.232, 333.054, 335.839, 342.172,
#       343.393, 345.536, 345.421, 346.302, 323.282, 321.084, 311.701, 300.138, 288.921, 278.883, 270.019, 275.492, 286.234, 300.949, 310.969, 326.029, 336.29, 345.442, 350.181, 349.298, 335.476, 336.572,
#       314.432, 291.666, 273.035, 257.909, 248.256, 248.914]
#   mode: val
# batch_size: 8
# iters: 50
# save_interval: 800
# log_iters: 50
# num_workers: 4
# seed: 1919810
# optimizer:
#   type: AdamW
# lr_scheduler:
#   type: StepDecay
#   learning_rate: 0.0002
#   step_size: 5000
#   gamma: 0.5
# loss:
#   types:
#   - type: MixedLoss
#     losses:
#     - type: CrossEntropyLoss_Smooth
#       smoothing: 0.05
#     - type: DiceLoss
#     coef: [1, 0.5]
#   coef: [1]
# model:
#   type: CX_Uper_4B_CA_FLASH_V6
#   backb: convnext_tiny
#   in_channels: 3
#   num_classes: 14
#   dropout_rate: 0
#   hsi_chs: 116
# ------------------------------------------------
# W0611 10:47:32.835469 1449699 gpu_resources.cc:116] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 12.6
# [2026-06-11 10:47:32,872] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:47:32,872] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:47:33,046] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# [2026-06-11 10:47:33,147] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:47:33,147] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:47:33,323] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# [2026-06-11 10:47:33,405] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:47:33,405] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:47:33,581] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/nn/layer/layers.py:2706: UserWarning: Skip loading for downsample_layers.0.0.weight. downsample_layers.0.0.weight receives a shape [96, 3, 4, 4], but the expected shape is [96, 2, 4, 4].
#   warnings.warn(f"Skip loading for {key}. " + str(err))
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# [2026-06-11 10:47:33,663] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:47:33,664] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:47:33,839] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/nn/layer/layers.py:2706: UserWarning: Skip loading for downsample_layers.0.0.weight. downsample_layers.0.0.weight receives a shape [96, 3, 4, 4], but the expected shape is [96, 116, 4, 4].
#   warnings.warn(f"Skip loading for {key}. " + str(err))
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/nn/layer/norm.py:885: UserWarning: When training, we now always track global mean and variance.
#   warnings.warn(
# 2026-06-11 10:48:11 [INFO]	[TRAIN] epoch: 1, iter: 50/50, loss: 0.5314, lr: 0.000200, batch_cost: 0.7512, reader_cost: 0.33873, ips: 10.6501 samples/sec | ETA 00:00:00
# 2026-06-11 10:48:11 [INFO]	Start evaluating (total_samples: 714, total_iters: 90)...
# 90/90 [==============================] - 65s 723ms/step - batch_cost: 0.7227 - reader cost: 0.6137
# <class 'paddle.nn.layer.conv.Conv2D'>'s flops has been counted
# Cannot find suitable count function for <class 'paddleseg.models.backbones.convnext.LayerNorm'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddle.nn.layer.common.Upsample'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.common.Linear'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.activation.GELU'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddleseg.models.backbones.convnext.Identity'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddle.nn.layer.norm.LayerNorm'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.pooling.AdaptiveAvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.norm.BatchNorm2D'>'s flops has been counted
# <class 'paddle.nn.layer.activation.ReLU'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.common.Dropout2D'>. Treat it as zero FLOPs.
# Total Flops: 91761534464     Total Params: 53610316
# /localnvme/project/MRSN/PaddleCD/paddleseg/utils/metrics.py:78: RuntimeWarning: invalid value encountered in divide
#   precision = intersect_area/pred_area
# /localnvme/project/MRSN/PaddleCD/paddleseg/utils/metrics.py:80: RuntimeWarning: invalid value encountered in divide
#   f1 = 2*(precision*recall)/(precision+recall)
# 2026-06-11 10:49:17 [INFO]	[EVAL] #Images: 714 F1: 0.3120, mIoU: 0.2189 Acc: 0.6408 Kappa: 0.5178
# 2026-06-11 10:49:17 [INFO]	[EVAL] Params: 115.52M  Trainable: 115.51M  FLOPs: 91.76G  FPS: 72.78
# 2026-06-11 10:49:17 [INFO]	[EVAL] Class IoU:
# [0.     0.4433 0.2818 0.346  0.2366 0.2026 0.2595 0.2535 0.2219 0.
#  0.8199 0.     0.     0.    ]
# 2026-06-11 10:49:17 [INFO]	[EVAL] Class Acc:
# [0.     0.619  0.5109 0.684  0.2832 0.3922 0.3696 0.4723 0.2808 0.
#  0.8988 0.12   0.0139 0.    ]
# 2026-06-11 10:49:17 [INFO]	[EVAL] Class F1:
# [0.     0.6143 0.4397 0.5141 0.3826 0.3369 0.4121 0.4044 0.3633 0.
#  0.901  0.     0.     0.    ]
# 2026-06-11 10:49:20 [INFO]	[EVAL] The model with the best validation mIoU (0.2189) was saved at iter 50.

# %%
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    # !CUDA_VISIBLE_DEVICES=0 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval
# Out:
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/utils/cpp_extension/extension_utils.py:712: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# 2026-06-11 10:49:23 [INFO]	Log file: ./log/train/cxup_4b_BW_CA_FLASH_v6_20260611_104923.log
# 2026-06-11 10:49:23 [INFO]
# ------------Environment Information-------------
# platform: Linux-5.15.0-92-generic-x86_64-with-glibc2.35
# Python: 3.10.20 | packaged by conda-forge | (main, Mar  5 2026, 16:42:22) [GCC 14.3.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_11.5.r11.5/compiler.30672275_0
# cudnn: 90.5
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: 0
# GPU: ['GPU 0: NVIDIA RTX', 'GPU 1: NVIDIA RTX']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#
#     mean2: [999.433, 986.904, 974.447, 960.982, 947.575, 935.621, 924.243, 915.542, 907.726, 905.25, 909.091, 907.068, 902.661, 901.638, 902.661, 905.772, 911.386, 915.995, 920.723, 926.349, 931.746, 938.978,
#       946.329, 961.263, 959.789, 957.446, 954.46, 955.459, 954.627, 948.609, 945.025, 944.374, 949.51, 955.58, 960.178, 970.076, 975.216, 984.512, 990.831, 985.008, 950.914, 919.385, 889.296, 862.777, 825.307,
#       788.723, 762.22, 743.14, 734.277, 732.632, 733.673, 742.012, 753.558, 775.226, 794.269, 801.276, 799.636, 804.197, 816.373, 821.174, 854.051, 868.974, 869.269, 866.709, 876.802, 871.139, 835.212,
#       802.712, 767.638, 740.126, 713.945, 702.162, 696.747, 712.822, 763.065, 827.185, 896.042, 921.248, 940.171, 972.243, 1006.637, 1009.505, 990.419, 976.739, 949.181, 937.05, 925.81, 927.843, 919.324,
#       920.378, 923.239, 929.856, 874.345, 869.418, 844.642, 813.909, 782.993, 753.203, 724.175, 731.045, 750.315, 782.591, 804.119, 842.056, 869.63, 897.671, 916.529, 914.812, 880.695, 884.894, 828.311,
#       769.462, 720.269, 678.44, 650.35, 648.275]
#     std1: [377.969, 454.927, 509.648, 663.225, 4.606, 4.104]
#     std2: [262.658, 264.218, 266.238, 268.52, 271.314, 274.417, 277.69, 281.143, 283.609, 285.875, 290.075, 291.693, 292.987, 294.783, 297.264, 300.135, 304.173, 307.715, 311.216, 315.269, 319.666, 324.806,
#       330.629, 339.265, 342.287, 345.117, 347.39, 349.633, 349.462, 345.958, 341.043, 335.233, 330.31, 325.421, 321.263, 320.142, 319.573, 322.109, 324.541, 323.369, 313.437, 304.176, 295.106, 287.168,
#       275.492, 263.964, 255.904, 250.446, 248.273, 248.307, 249.869, 253.019, 256.607, 263.015, 268.048, 269.423, 268.091, 269.031, 271.468, 271.956, 280.045, 282.251, 280.115, 277.253, 279.424, 276.046,
#       262.96, 250.279, 237.595, 227.998, 219.871, 217.434, 217.565, 224.737, 242.565, 265.104, 287.018, 296.602, 304.602, 317.398, 332.026, 335.748, 332.952, 333.034, 330.232, 333.054, 335.839, 342.172,
#       343.393, 345.536, 345.421, 346.302, 323.282, 321.084, 311.701, 300.138, 288.921, 278.883, 270.019, 275.492, 286.234, 300.949, 310.969, 326.029, 336.29, 345.442, 350.181, 349.298, 335.476, 336.572,
#       314.432, 291.666, 273.035, 257.909, 248.256, 248.914]
#   mode: val
# batch_size: 8
# iters: 40000
# save_interval: 800
# log_iters: 50
# num_workers: 4
# seed: 1919810
# optimizer:
#   type: AdamW
# lr_scheduler:
#   type: StepDecay
#   learning_rate: 0.0002
#   step_size: 5000
#   gamma: 0.5
# loss:
#   types:
#   - type: MixedLoss
#     losses:
#     - type: CrossEntropyLoss_Smooth
#       smoothing: 0.05
#     - type: DiceLoss
#     coef: [1, 0.5]
#   coef: [1]
# model:
#   type: CX_Uper_4B_CA_FLASH_V6
#   backb: convnext_tiny
#   in_channels: 3
#   num_classes: 14
#   dropout_rate: 0
#   hsi_chs: 116
# ------------------------------------------------
# W0611 10:49:24.074285 1520860 gpu_resources.cc:116] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 12.6
# [2026-06-11 10:49:24,120] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:49:24,120] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:49:24,301] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# [2026-06-11 10:49:24,405] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:49:24,405] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:49:24,579] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# [2026-06-11 10:49:24,668] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:49:24,668] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:49:24,843] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/nn/layer/layers.py:2706: UserWarning: Skip loading for downsample_layers.0.0.weight. downsample_layers.0.0.weight receives a shape [96, 3, 4, 4], but the expected shape is [96, 2, 4, 4].
#   warnings.warn(f"Skip loading for {key}. " + str(err))
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# [2026-06-11 10:49:24,905] [    INFO] download.py:116 - unique_endpoints {''}
# [2026-06-11 10:49:24,905] [    INFO] download.py:248 - File /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams md5 checking...
# [2026-06-11 10:49:25,081] [    INFO] download.py:155 - Found /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/nn/layer/layers.py:2706: UserWarning: Skip loading for downsample_layers.0.0.weight. downsample_layers.0.0.weight receives a shape [96, 3, 4, 4], but the expected shape is [96, 116, 4, 4].
#   warnings.warn(f"Skip loading for {key}. " + str(err))
# model load from /home/23039356r/.cache/paddle/hapi/weights/convnext_tiny_1k_224.pdparams
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/nn/layer/norm.py:885: UserWarning: When training, we now always track global mean and variance.
#   warnings.warn(
# 2026-06-11 10:50:01 [INFO]	[TRAIN] epoch: 1, iter: 50/40000, loss: 0.5313, lr: 0.000200, batch_cost: 0.7317, reader_cost: 0.32547, ips: 10.9333 samples/sec | ETA 08:07:11
# 2026-06-11 10:50:36 [INFO]	[TRAIN] epoch: 1, iter: 100/40000, loss: 0.4797, lr: 0.000200, batch_cost: 0.6967, reader_cost: 0.32678, ips: 11.4824 samples/sec | ETA 07:43:19
# 2026-06-11 10:51:12 [INFO]	[TRAIN] epoch: 1, iter: 150/40000, loss: 0.4673, lr: 0.000200, batch_cost: 0.7165, reader_cost: 0.34496, ips: 11.1650 samples/sec | ETA 07:55:53
# 2026-06-11 10:51:46 [INFO]	[TRAIN] epoch: 1, iter: 200/40000, loss: 0.4568, lr: 0.000200, batch_cost: 0.6920, reader_cost: 0.32095, ips: 11.5599 samples/sec | ETA 07:39:03
# 2026-06-11 10:52:22 [INFO]	[TRAIN] epoch: 1, iter: 250/40000, loss: 0.4496, lr: 0.000200, batch_cost: 0.7121, reader_cost: 0.34198, ips: 11.2345 samples/sec | ETA 07:51:45
# 2026-06-11 10:52:57 [INFO]	[TRAIN] epoch: 1, iter: 300/40000, loss: 0.4478, lr: 0.000200, batch_cost: 0.7064, reader_cost: 0.33500, ips: 11.3243 samples/sec | ETA 07:47:25

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     MD_PATH = f'output/{model_name}/best_model/model.pdparams'
#     !CUDA_VISIBLE_DEVICES=1 python PaddleCD/val.py --batch_size 32 --config $COF_PATH --model_path $MD_PATH
