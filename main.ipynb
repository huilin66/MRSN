# %%
model_list = [
    'unet_BW',
    'deeplabv3p_BW',
    'ocrnet_BW',
    'segformer_BW',
    'cxup_1b_BW',
    'cxup_2b_BW',
    'cxup_3b_BW',
    'cxup_4b_BW',
    'cxup_4b2h_BW',
    'cxup_4b_BW_PMRG_v2',
    'cxup_4b_BW_lossV2',
    'cxup_4b_BW_PMRG_v2_lossV2',
]

# %%
# pre test
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    # !python -m paddle.distributed.launch python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 20 --save_interval 100 --batch_size=1 --log_iters 10 --pre_test
    # !CUDA_VISIBLE_DEVICES=0 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 50 --save_interval 100 --batch_size=8 --log_iters 10 --pre_test

# %%
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    # !CUDA_VISIBLE_DEVICES=0 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     MD_PATH = f'output/{model_name}/best_model/model.pdparams'
#     !CUDA_VISIBLE_DEVICES=0 python PaddleCD/val.py --batch_size 32 --config $COF_PATH --model_path $MD_PATH

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     !CUDA_VISIBLE_DEVICES=0 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --resume_model $SAVE_DIR/iter_17600 --do_eval
