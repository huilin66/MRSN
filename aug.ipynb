# %%
model_list = [
    'unet_BW',
    'deeplabv3p_BW',
    'ocrnet_BW',
    'segformer_BW',
    'highdan_BW',
    'cxup_1b_BW',
    'cxup_2b_BW',
    'cxup_3b_BW',
    'cxup_4b_BW',
    'MRSN_BW',
    'cxup_4b_BW_PMRG_',
    'cxup_4b_BW_ML',
    'cxup_4b_BW_PMRG_ML',
]

# %%
# # # pre test
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     # !python -m paddle.distributed.launch python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 20 --save_interval 100 --batch_size=1 --log_iters 10 --pre_test
#     !CUDA_VISIBLE_DEVICES=1 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 50 --save_interval 100 --batch_size=8 --log_iters 10 --pre_test

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     !CUDA_VISIBLE_DEVICES=1 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval

# %%
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    MD_PATH = f'output/{model_name}/best_model/model.pdparams'
    # !python PaddleCD/val.py --batch_size 16 --config $COF_PATH --model_path $MD_PATH

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     MD_PATH = f'output/{model_name}/best_model/model.pdparams'
#     SAVE_DIR = f'ana/{model_name}'
#     !python tools/per_image_miou.py --config $COF_PATH --model_path $MD_PATH --output_dir $SAVE_DIR --batch_size 32

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     MD_PATH = f'output/{model_name}/best_model/model.pdparams'
#     SAVE_DIR = f'ana/{model_name}'
#     !python tools/cam_analysis.py --config $COF_PATH --model_path $MD_PATH --output_dir $SAVE_DIR --cam_class 1 --topk 30

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     MD_PATH = f'output/{model_name}/best_model/model.pdparams'
#     SAVE_DIR = f'ana/{model_name}/prototype_tsne'
#     !python tools/tsne_prototype_analysis.py --model_names $model_name --output_dir $SAVE_DIR
