# %%
model_list = [
    # 'unet_BW',
    # 'deeplabv3p_BW',
    # 'ocrnet_BW',
    # 'segformer_BW',
    # 'cxup_1b_BW',
    # 'cxup_2b_BW',
    # 'cxup_3b_BW',
    # 'cxup_4b_BW',
    # 'cxup_4b2h_BW',
    # 'cxup_4b_BW_CA_FLASH_v4',
    # 'cxup_4b_BW_CA_FLASH_v3',
    # 'cxup_4b_BW_CA_FLASH_v2',
    # 'cxup_4b_BW_CA_FLASH_v1',
    'cxup_4b_BW_CA_FLASH_v6_loss',
]

# %%
# # pre test
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    # !python -m paddle.distributed.launch python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 20 --save_interval 100 --batch_size=1 --log_iters 10
    # !CUDA_VISIBLE_DEVICES=1 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval --iters 50 --save_interval 100 --batch_size=8 --log_iters 10
# Out:
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/utils/cpp_extension/extension_utils.py:712: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# 2026-06-11 10:47:37 [INFO]	Log file: ./log/train/cxup_4b_BW_CA_FLASH_v6_loss_20260611_104737.log
# 2026-06-11 10:47:37 [INFO]
# ------------Environment Information-------------
# platform: Linux-5.15.0-92-generic-x86_64-with-glibc2.35
# Python: 3.10.20 | packaged by conda-forge | (main, Mar  5 2026, 16:42:22) [GCC 14.3.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_11.5.r11.5/compiler.30672275_0
# cudnn: 90.5
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: 1
# GPU: ['GPU 0: NVIDIA RTX', 'GPU 1: NVIDIA RTX']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PaddlePaddle: 3.3.1
# OpenCV: 4.13.0
# ...

# %%
for model_name in model_list:
    COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
    SAVE_DIR = f'output/{model_name}'
    # !CUDA_VISIBLE_DEVICES=1 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --do_eval
# Out:
# /home/23039356r/.conda/envs/mrsn/lib/python3.10/site-packages/paddle/utils/cpp_extension/extension_utils.py:712: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# 2026-06-11 10:49:28 [INFO]	Log file: ./log/train/cxup_4b_BW_CA_FLASH_v6_loss_20260611_104928.log
# 2026-06-11 10:49:28 [INFO]
# ------------Environment Information-------------
# platform: Linux-5.15.0-92-generic-x86_64-with-glibc2.35
# Python: 3.10.20 | packaged by conda-forge | (main, Mar  5 2026, 16:42:22) [GCC 14.3.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_11.5.r11.5/compiler.30672275_0
# cudnn: 90.5
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: 1
# GPU: ['GPU 0: NVIDIA RTX', 'GPU 1: NVIDIA RTX']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PaddlePaddle: 3.3.1
# OpenCV: 4.13.0
# ...

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     MD_PATH = f'output/{model_name}/best_model/model.pdparams'
#     !CUDA_VISIBLE_DEVICES=0 python PaddleCD/val.py --batch_size 8 --config $COF_PATH --model_path $MD_PATH

# %%
# for model_name in model_list:
#     COF_PATH = f'PaddleCD/c2seg_config/{model_name}.yml'
#     SAVE_DIR = f'output/{model_name}'
#     !CUDA_VISIBLE_DEVICES=1 python PaddleCD/train.py --save_dir $SAVE_DIR --config $COF_PATH --resume_model $SAVE_DIR/iter_13600 --do_eval
